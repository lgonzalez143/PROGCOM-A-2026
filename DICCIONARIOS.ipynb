# %% [markdown]
# <a href="https://colab.research.google.com/github/lgonzalez143/PROGCOM-A-2026/blob/main/DICCIONARIOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DICCIONARIOS
# 1. Tipo de datos como las listas. **Si son mutables**
# 2. Se utilizan para almacenar datos en pares, clave:valor , La clave siempre **DEBE SER ALFANUMÉRICA**
#
# ```
# variable={clave:valor}
# ```
# 3. Los diccionarios son colecciones ordenadas, modificables y **NO PERMITE DUPLICADOS**.

# %%
estudiante={"nombre":"Luisa",
            "ID":"U00186544",
            "Edad":18,
            "Carrera":"Ingeniería Industrial"}
print(estudiante)
# Out:
# {'nombre': 'Luisa', 'ID': 'U00186544', 'Edad': 18, 'Carrera': 'Ingeniería Industrial'}

# %%
estudiante["Edad"]
# Out:
# 18

# %%
galletas=["angelitos","diablitos","dinosaurios"]
galletas_precio=[20000,15000,25000]
galletas_cant=[3,5,10]

# %%
def menu_galletas():
  for i in range(3):
    print(f"{galletas[i]}:{galletas_precio[i]}, cantidad:{galletas_cant[i]}")

# %%
menu_galletas()
# Out:
# angelitos:20000, cantidad:3
# diablitos:15000, cantidad:5
# dinosaurios:25000, cantidad:10

# %%
galleta={"tipo de galleta": ["angelitos","diablitos","dinosaurios"],
         "precio":[20000,15000,25000],
         "cantidad":[3,5,10]}

# %%
galleta
# Out:
# {'tipo de galleta': ['angelitos', 'diablitos', 'dinosaurios'],
#  'precio': [20000, 15000, 25000],
#  'cantidad': [3, 5, 10]}

# %% [markdown]
# ##Impresión de elementos en un diccionario
# 1. Sirve si quiero imprimir todos los elementos de una clave
#
# ```
# print(diccionario[clave])
# ```
# 2. Quiero imprimir las claves
#
# ```
# print(diccionario.keys())
# ```
# 3. Ingresando a un elemento en particular del valor

# %%
galleta["cantidad"]
# Out:
# [3, 5, 10]

# %%
galleta["tipo de galleta"]
# Out:
# ['angelitos', 'diablitos', 'dinosaurios']

# %%
galleta.keys()
# Out:
# dict_keys(['tipo de galleta', 'precio', 'cantidad'])

# %%
galleta["precio"][1]
# Out:
# 15000
