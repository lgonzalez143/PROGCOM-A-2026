# %% [markdown]
# #Ejercicios con If else 😛
# Del 5 al 15

# %%
import math

a = float(input("Valor de a: "))
b = float(input("Valor de b: "))
c = float(input("Valor de c: "))
discriminante = b**2 - 4*a*c
if discriminante < 0:
    print("La ecuación no tiene soluciones reales.")
else:
    x1 = (-b + math.sqrt(discriminante)) / (2*a)
    x2 = (-b - math.sqrt(discriminante)) / (2*a)
    print(f"Soluciones: x1 = {x1}, x2 = {x2}")
# Out:
# Valor de a: 5
# Valor de b: 8
# Valor de c: 2
# Soluciones: x1 = -0.31010205144336445, x2 = -1.2898979485566355

# %%
num = int(input("Introduce un número: "))
if num%2 == 0:
    print("Es par")
else:
    print("Es impar")
# Out:
# Introduce un número: 82
# Es par

# %%
year = int(input("Introduce el año: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
  print("Es año bisiesto")
else:
  print("No es un año bisiesto")
# Out:
# Introduce el año: 2020
# Es año bisiesto

# %%
nombre = input("Nombre: ")
edad = int(input("Edad: "))
if edad >= 70:
   print(f"El usuario {nombre} pertenece a la tercera edad. Se le da prioridad en la fila.")
else:
  print(f"El usuario {nombre} debe esperar su turno normal en la fila.")
# Out:
# Nombre: Juan
# Edad: 25
# El usuario Juan debe esperar su turno normal en la fila.

# %%
n1 = float(input("Número 1: "))
n2 = float(input("Número 2: "))
n3 = float(input("Número 3: "))
if n1 >= n2 and n1 >= n3:
   mayor = n1
elif n2 >= n1 and n2 >= n3:
   mayor = n2
else:
  mayor = n3
print(f"El mayor es: {mayor}")
# Out:
# Número 1: 56
# Número 2: 45
# Número 3: 82
# El mayor es: 82.0

# %%
l1 = float(input("Lado 1: "))
l2 = float(input("Lado 2: "))
l3 = float(input("Lado 3: "))
if l1 == l2 == l3:
    print("Es un triángulo Equilátero")
elif l1 == l2 or l1 == l3 or l2 == l3:
    print("Es un triángulo Isósceles")
else:
    print("Es un triángulo Escaleno")
# Out:
# Lado 1: 5
# Lado 2: 5
# Lado 3: 3
# Es un triángulo Isósceles

# %%
nombre = input("Nombre: ")
peso = float(input("Peso (kg): "))
altura = float(input("Altura (m): "))
imc = peso / (altura**2)
if imc < 18.5:
    cat, desc = "Bajo peso", "Consulte a un nutricionista para aumentar su masa muscular."
elif 18.5 <= imc < 25:
    cat, desc = "Normal", "Mantén tu estilo de vida como lo vienes llevando."
elif 25 <= imc < 30:
    cat, desc = "Sobrepeso", "Se recomienda consultar,realizar actividad física y llevar un dieta estricta."
else:
    cat, desc = "Obesidad", "Acuda al médico para prevenir mas problemas de salud."
print(f"\nUsuario: {nombre}\nCategoría: {cat}\nRecomendación: {desc}")
# Out:
# Nombre: Lola
# Peso (kg): 54
# Altura (m): 1.59
#
# Usuario: Lola
# Categoría: Normal
# Recomendación: Mantén tu estilo de vida como lo vienes llevando.

# %%
n1 = float(input("Número 1: "))
n2 = float(input("Número 2: "))
op = input("Operación (+, -, *, /): ")
if op == "+":
    print(f"Resultado: {n1 + n2}")
elif op == "-":
    print(f"Resultado: {n1 - n2}")
elif op == "*":
    print(f"Resultado: {n1 * n2}")
elif op == "/":
    if n2 != 0:
        print(f"Resultado: {n1 / n2}")
    else:
        print("Error: No se puede dividir por cero.")
else:
    print("Operación no válida.")
# Out:
# Número 1: 25
# Número 2: 46
# Operación (+, -, *, /): -
# Resultado: -21.0

# %%
nota = float(input("Nota (0-100): "))
if 90 <= nota <= 100:
 letra = "A"
elif 80 <= nota < 90:
 letra = "B"
elif 70 <= nota < 80:
 letra = "C"
elif 60 <= nota < 70:
 letra = "D"
else:
 letra = "F"
print(f"Tu calificación es: {letra}")
# Out:
# Nota (0-100): 92
# Tu calificación es: A

# %%
dia = int(input("Número (1-7): "))
if dia == 1: print("Lunes")
elif dia == 2: print("Martes")
elif dia == 3: print("Miércoles")
elif dia == 4: print("Jueves")
elif dia == 5: print("Viernes")
elif dia == 6: print("Sábado")
elif dia == 7: print("Domingo")
else:print("Número fuera de rango.")
# Out:
# Número (1-7): 2
# Martes

# %%
a = float(input("Lado A: "))
b = float(input("Lado B: "))
c = float(input("Lado C: "))

if (a + b > c) and (a + c > b) and (b + c > a):
    if a == b == c:
        tipo = "Triangulo Equilátero"
    elif a == b or a == c or b == c:
        tipo = "Triangulo Isósceles"
    else:
        tipo = "Triangulo Escaleno"
    print(f"Es un triángulo válido y es de tipo {tipo}.")
else:
    print("No se puede formar un triángulo con esas medidas.")
# Out:
# Lado A: 6
# Lado B: 6
# Lado C: 9
# Es un triángulo válido y es de tipo Triangulo Isósceles.

# %% [markdown]
# #Ejercicios if elif else

# %%
import math
a = float(input("Valor de a: "))
b = float(input("Valor de b: "))
c = float(input("Valor de c: "))
disc = b**2 - 4*a*c
if disc > 0:
    x1 = (-b + math.sqrt(disc)) / (2*a)
    x2 = (-b - math.sqrt(disc)) / (2*a)
    print(f"Dos soluciones reales: {x1} y {x2}")
elif disc == 0:
    x = -b / (2*a)
    print(f"Una solución real (doble): {x}")
else:
    print("La ecuación tiene soluciones imaginarias.")
# Out:
# Valor de a: 5
# Valor de b: 2
# Valor de c: 9
# La ecuación tiene soluciones imaginarias.

# %%
num = int(input("Número: "))
if num % 2 == 0:
    print("Es Par")
else:
    print("Es Impar")
# Out:
# Número: 456
# Es Par

# %%
year = int(input("Año: "))

if year % 400 == 0:
    print("Es bisiesto")
elif year % 100 == 0:
    print("No es bisiesto")
elif year % 4 == 0:
    print("El año es bisiesto")
else:
    print("El año no es bisiesto")
# Out:
# Año: 1979
# El año no es bisiesto

# %%
nombre = input("Nombre: ")
edad = int(input("Edad: "))

if edad >= 70:
    print(f"Prioridad para {nombre}: Persona de la tercera edad.")
elif edad >= 0:
    print(f"{nombre} debe esperar su turno .")
else:
    print("Edad no válida.")
# Out:
# Nombre: Paola
# Edad: 45
# Paola debe esperar su turno .

# %%
a = float(input("A: "))
b = float(input("B: "))
c = float(input("C: "))

if a >= b and a >= c:
    print(f"El mayor es {a}")
elif b >= a and b >= c:
    print(f"El mayor es {b}")
else:
    print(f"El mayor es {c}")
# Out:
# A: 25
# B: 45
# C: 75
# El mayor es 75.0

# %%
l1 = float(input("Lado 1: "))
l2 = float(input("Lado 2: "))
l3 = float(input("Lado 3: "))

if l1 == l2 == l3:
    print("Equilátero")
elif l1 == l2 or l1 == l3 or l2 == l3:
    print("Isósceles")
else:
    print("Escaleno")
# Out:
# Lado 1: 3
# Lado 2: 6
# Lado 3: 9
# Escaleno

# %%
peso = float(input("Peso (kg): "))
altura = float(input("Altura (m): "))
imc = peso / (altura**2)

if imc < 18.5:
    print(f"IMC: {imc:.2f} - Bajo peso. Debes mejorar tu alimentación.")
elif imc < 25:
    print(f"IMC: {imc:.2f} - Normal. ¡Sigue así!")
elif imc < 30:
    print(f"IMC: {imc:.2f} - Sobrepeso. Considera hacer ejercicio.")
else:
    print(f"IMC: {imc:.2f} - Obesidad. Consulta a un médico.")
# Out:
# Peso (kg): 80
# Altura (m): 1.70
# IMC: 27.68 - Sobrepeso. Considera hacer ejercicio.

# %%
n1 = float(input("Num 1: "))
n2 = float(input("Num 2: "))
op = input("Operación (+, -, *, /): ")

if op == "+":
    print(f"Suma: {n1 + n2}")
elif op == "-":
    print(f"Resta: {n1 - n2}")
elif op == "*":
    print(f"Multiplicación: {n1 * n2}")
elif op == "/":
    if n2 != 0:
        print(f"División: {n1 / n2}")
    else:
        print("Error: División por cero.")
else:
    print("Operación no reconocida.")
# Out:
# Num 1: 456
# Num 2: 789
# Operación (+, -, *, /): +
# Suma: 1245.0

# %%
nota = float(input("Nota (0-100): "))

if nota >= 90:
    print("Calificación: A")
elif nota >= 80:
    print("Calificación: B")
elif nota >= 70:
    print("Calificación: C")
elif nota >= 60:
    print("Calificación: D")
else:
    print("Calificación: F")
# Out:
# Nota (0-100): 25
# Calificación: F

# %%
dia = int(input("Número del 1 al 7: "))

if dia == 1: print("Lunes")
elif dia == 2: print("Martes")
elif dia == 3: print("Miércoles")
elif dia == 4: print("Jueves")
elif dia == 5: print("Viernes")
elif dia == 6: print("Sábado")
elif dia == 7: print("Domingo")
else: print("Error: solo números del 1 al 7.")
# Out:
# Número del 1 al 7: 7
# Domingo

# %%
a = float(input("Lado A: "))
b = float(input("Lado B: "))
c = float(input("Lado C: "))

# Primero validamos si es un triángulo posible
if a + b <= c or a + c <= b or b + c <= a:
    print("No es un triángulo válido.")
# Si pasa la validación, clasificamos
elif a == b == c:
    print("Triángulo Equilátero.")
elif a == b or a == c or b == c:
    print("Triángulo Isósceles.")
else:
    print("Triángulo Escaleno.")
# Out:
# Lado A: 32
# Lado B: 32
# Lado C: 32
# Triángulo Equilátero.

# %% [markdown]
# #Ejercicios if ternario
# 5 al 15

# %%
import math
a, b, c = float(input("a: ")), float(input("b: ")), float(input("c: "))
d = b**2 - 4*a*c
print(f"Raíces: {(-b+math.sqrt(d))/(2*a)} y {(-b-math.sqrt(d))/(2*a)}" if d >= 0 else "Sin soluciones reales")
# Out:
# a: 50
# b: 20
# c: 80
# Sin soluciones reales

# %%
n = int(input("Número: "))
print("Par" if n % 2 == 0 else "Impar")
# Out:
# Número: 741
# Impar

# %%
y = int(input("Año: "))
print("Bisiesto" if (y % 400 == 0 or (y % 4 == 0 and y % 100 != 0)) else "No bisiesto")
# Out:
# Año: 2011
# No bisiesto

# %%
nom, ed = input("Nombre: "), int(input("Edad: "))
print(f"{nom} tiene PRIORIDAD" if ed >= 70 else f"{nom} espera turno normal")
# Out:
# Nombre: Juana
# Edad: 84
# Juana tiene PRIORIDAD

# %%
a, b, c = float(input("A: ")), float(input("B: ")), float(input("C: "))
mayor = a if (a >= b and a >= c) else (b if b >= c else c)
print(f"El mayor es: {mayor}")
# Out:
# A: 32
# B: 78
# C: 65
# El mayor es: 78.0

# %%
l1, l2, l3 = float(input("L1: ")), float(input("L2: ")), float(input("L3: "))
tipo = "Equilátero" if l1 == l2 == l3 else ("Isósceles" if l1 == l2 or l1 == l3 or l2 == l3 else "Escaleno")
print(tipo)
# Out:
# L1: 14
# L2: 25
# L3: 36
# Escaleno

# %%
p, alt = float(input("Kg: ")), float(input("m: "))
imc = p / alt**2
cat = "Bajo" if imc < 18.5 else ("Normal" if imc < 25 else ("Sobrepeso" if imc < 30 else "Obesidad"))
print(f"IMC: {imc:.2f} - Categoría: {cat}")
# Out:
# Kg: 65
# m: 1.70
# IMC: 22.49 - Categoría: Normal

# %%
n1, n2 = float(input("n1: ")), float(input("n2: "))
op = input("Op (+,-,*,/): ")
res = n1+n2 if op=="+" else (n1-n2 if op=="-" else (n1*n2 if op=="*" else (n1/n2 if op=="/" and n2!=0 else "Error")))
print(f"Resultado: {res}")
# Out:
# n1: 654
# n2: 987
# Op (+,-,*,/): +
# Resultado: 1641.0

# %%
nota = float(input("Nota: "))
letra = "A" if nota >= 90 else ("B" if nota >= 80 else ("C" if nota >= 70 else ("D" if nota >= 60 else "F")))
print(f"Letra: {letra}")
# Out:
# Nota: 75
# Letra: C

# %%
d = int(input("Día (1-7): "))
nombre = "Lunes" if d==1 else ("Martes" if d==2 else ("Miercoles" if d==3 else ("Jueves" if d==4 else ("Viernes" if d==5 else ("Sabado" if d==6 else ("Domingo" if d==7 else "Error"))))))
print(nombre)
# Out:
# Día (1-7): 3
# Miercoles

# %%
a, b, c = float(input("A: ")), float(input("B: ")), float(input("C: "))
es_v = True if (a+b > c and a+c > b and b+c > a) else False
tipo = ("Equilátero" if a==b==c else ("Isósceles" if a==b or a==c or b==c else "Escaleno")) if es_v else "No es triángulo"
print(tipo)
# Out:
# A: 45
# B: 65
# C: 45
# Isósceles
